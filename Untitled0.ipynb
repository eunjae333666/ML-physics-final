# %% [markdown]
# <a href="https://colab.research.google.com/github/eunjae333666/ML-physics-final/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. 데이터 전처리
# 데이터 셋 다운로드 해서 그 $Y \times r$으로 변환하면 될듯?

# %% [markdown]
# ## 2. GNN 으로 manifold U(V,T)학습?
# 잘 모르겟음니다. 가장 기학응스러운부분

# %% [markdown]
# ## 3. 학습한거에서 메트릭($g_{\mu\nu}$) 찾기

# %% [markdown]
# ## 4. geodesic 미방 풀기

# %% [markdown]
# ## 4. 결과 검증 및 시각화
# 두개를 걍 따로 하는 것이 좋을 것 같다.
# 검증 먼저 하기.
# 효율 벤치마크도 하면 좋을듯?(교수님께서 신경이나 쓰시는진 잘 모르겠으나.......... 왜 굳이 이걸 GNN으로 풀어야하는거예요? 라는거의 방어가 될수있을수도...)
